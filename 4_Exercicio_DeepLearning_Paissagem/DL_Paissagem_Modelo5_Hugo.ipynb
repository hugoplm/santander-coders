# %% [markdown]
# <a href="https://colab.research.google.com/github/hugoplm/santander-coders/blob/master/4_Exercicio_DeepLearning_Paissagem/DL_Paissagem_Modelo5_Hugo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Baixando os Dados

# %%
# !pip install -Uqqq gdown
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#   Building wheel for gdown (PEP 517) ... done

# %%
# !gdown 1ORgjWsWnGHdmi7wOZZV64GbQNE4SXkh7
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ORgjWsWnGHdmi7wOZZV64GbQNE4SXkh7
# To: /content/seg_train.zip
# 100% 215M/215M [00:01<00:00, 151MB/s]

# %%
import shutil

# %%
shutil.unpack_archive('seg_train.zip', 'data')

# %% [markdown]
# # Carregando os Dados

# %%
import glob
import cv2
import numpy as np
import matplotlib.pyplot as plt
from random import randint
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split

# %%
path = "/content/data/seg_train/**/*.jpg"

# %%
X = []
y = []

for files in glob.glob(path, recursive=True):
  image = cv2.imread(files)
  image = cv2.resize(image, (75,75))
  X.append(image)
  y.append(files.split('/')[-2])

# %%
X = np.array(X)
y = np.array(y)
print(X.shape)
print(y.shape)
# Out:
# (14034, 75, 75, 3)
# (14034,)

# %%
f, ax = plt.subplots(5,5)
f.subplots_adjust(0,0,3,3)
for i in range(0,5,1):
  for j in range(0,5,1):
    rnd_number = randint(0,len(X))
    ax[i,j].imshow(X[rnd_number])
    ax[i,j].set_title(y[rnd_number])
    ax[i,j].axis('off')

# %% [markdown]
# # Pré-processamento dos Dados

# %%
X_train, X_val, y_train, y_val = train_test_split(
     X, y, stratify=y, test_size=0.33, random_state=42)

# %%
hot = OneHotEncoder()
y_train = hot.fit_transform(y_train.reshape(-1,1)).toarray()
y_val = hot.transform(y_val.reshape(-1,1)).toarray()

# %%
X_train = X_train / 255
X_val = X_val / 255

# %% [markdown]
# Distribuição das Classes

# %%
import seaborn as sns
sns.countplot(y);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# #Modelo Deep Learning

# %% [markdown]
# ## Carregando as Bibliotecas

# %%
from tensorflow.python.keras.layers import Input, Dense, Activation, Dropout, Flatten
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.callbacks import EarlyStopping

from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Modelo 3
#
# Maior quantidade de camadas e de neurônios

# %% [markdown]
# ### Definição da Arquitetura

# %%
rede = Sequential()

rede.add(Flatten())
rede.add(Dense(32,  input_dim = X_train.shape[1]*X_train.shape[2]*X_train.shape[3]))
rede.add(Activation('relu'))
rede.add(Dense(64))
rede.add(Activation('relu'))
rede.add(Dense(64))
rede.add(Activation('relu'))
rede.add(Dense(128))
rede.add(Activation('relu'))
rede.add(Dense(128))
rede.add(Activation('relu'))
rede.add(Dense(6))
rede.add(Activation('softmax'))

# %%
es = EarlyStopping(monitor = 'val_loss', 
                   min_delta = 0.001, 
                   patience = 10, 
                   verbose = 1, 
                   mode = 'auto')

# %%
rede.compile(loss = 'categorical_crossentropy', 
              optimizer = 'Adam', 
              metrics=['accuracy'])

# %% [markdown]
# ### Treinamento do Modelo

# %%
hist = rede.fit(X_train, 
                y_train, 
                epochs = 25,
                batch_size=32,
                verbose = 1,
                validation_data = (X_val, y_val),
                callbacks = [es])
# Out:
# Epoch 1/25
# 294/294 [==============================] - 5s 8ms/step - loss: 1.5761 - accuracy: 0.3061 - val_loss: 1.4801 - val_accuracy: 0.3724
# Epoch 2/25
# 294/294 [==============================] - 2s 6ms/step - loss: 1.4808 - accuracy: 0.3466 - val_loss: 1.4876 - val_accuracy: 0.3482
# Epoch 3/25
# 294/294 [==============================] - 2s 7ms/step - loss: 1.4620 - accuracy: 0.3532 - val_loss: 1.4367 - val_accuracy: 0.3692
# Epoch 4/25
# 294/294 [==============================] - 2s 6ms/step - loss: 1.4514 - accuracy: 0.3569 - val_loss: 1.5372 - val_accuracy: 0.3411
# Epoch 5/25
# 294/294 [==============================] - 2s 7ms/step - loss: 1.4361 - accuracy: 0.3719 - val_loss: 1.4433 - val_accuracy: 0.3683
# Epoch 6/25
# 294/294 [==============================] - 2s 6ms/step - loss: 1.4327 - accuracy: 0.3700 - val_loss: 1.4888 - val_accuracy: 0.3320
# Epoch 7/25
# 294/294 [==============================] - 2s 7ms/step - loss: 1.4302 - accuracy: 0.3730 - val_loss: 1.4875 - val_accuracy: 0.3415
# Epoch 8/25
# 294/294 [==============================] - 2s 7ms/step - loss: 1.4255 - accuracy: 0.3694 - val_loss: 1.4282 - val_accuracy: 0.3856
# Epoch 9/25
# 294/294 [==============================] - 2s 7ms/step - loss: 1.4195 - accuracy: 0.3798 - val_loss: 1.4234 - val_accuracy: 0.3659
# Epoch 10/25
# 294/294 [==============================] - 2s 7ms/step - loss: 1.4042 - accuracy: 0.3827 - val_loss: 1.4383 - val_accuracy: 0.3547
# Epoch 11/25
# 294/294 [==============================] - 2s 7ms/step - loss: 1.4117 - accuracy: 0.3802 - val_loss: 1.4546 - val_accuracy: 0.3573
# Epoch 12/25
# 294/294 [==============================] - 2s 7ms/step - loss: 1.4136 - accuracy: 0.3826 - val_loss: 1.4335 - val_accuracy: 0.3778
# Epoch 13/25
# 294/294 [==============================] - 2s 7ms/step - loss: 1.4189 - accuracy: 0.3725 - val_loss: 1.4718 - val_accuracy: 0.3694
# Epoch 14/25
# 294/294 [==============================] - 2s 7ms/step - loss: 1.3962 - accuracy: 0.3815 - val_loss: 1.4485 - val_accuracy: 0.3696
# Epoch 15/25
# 294/294 [==============================] - 2s 7ms/step - loss: 1.4058 - accuracy: 0.3811 - val_loss: 1.4206 - val_accuracy: 0.3845
# Epoch 16/25
# 294/294 [==============================] - 2s 7ms/step - loss: 1.3934 - accuracy: 0.3907 - val_loss: 1.4132 - val_accuracy: 0.3750
# Epoch 17/25
# 294/294 [==============================] - 2s 7ms/step - loss: 1.4024 - accuracy: 0.3869 - val_loss: 1.4264 - val_accuracy: 0.3843
# Epoch 18/25
# 294/294 [==============================] - 2s 7ms/step - loss: 1.4115 - accuracy: 0.3811 - val_loss: 1.4208 - val_accuracy: 0.3860
# Epoch 19/25
# 294/294 [==============================] - 2s 7ms/step - loss: 1.3880 - accuracy: 0.3918 - val_loss: 1.4363 - val_accuracy: 0.3806
# Epoch 20/25
# 294/294 [==============================] - 2s 7ms/step - loss: 1.3804 - accuracy: 0.3937 - val_loss: 1.4218 - val_accuracy: 0.3851
# Epoch 21/25
# 294/294 [==============================] - 2s 7ms/step - loss: 1.4006 - accuracy: 0.3923 - val_loss: 1.4368 - val_accuracy: 0.3739
# Epoch 22/25
# 294/294 [==============================] - 2s 7ms/step - loss: 1.3842 - accuracy: 0.3916 - val_loss: 1.4198 - val_accuracy: 0.3830
# Epoch 23/25
# 294/294 [==============================] - 2s 7ms/step - loss: 1.3796 - accuracy: 0.3967 - val_loss: 1.4544 - val_accuracy: 0.3586
# Epoch 24/25
# 294/294 [==============================] - 2s 7ms/step - loss: 1.3883 - accuracy: 0.3993 - val_loss: 1.4209 - val_accuracy: 0.3856
# Epoch 25/25
# 294/294 [==============================] - 2s 7ms/step - loss: 1.3766 - accuracy: 0.3992 - val_loss: 1.4272 - val_accuracy: 0.3769

# %% [markdown]
# ### Avaliação do Modelo

# %%
pred = rede.predict(X_val)

accuracy_score(y_val.argmax(1), pred.argmax(1))
# Out:
# 0.37694300518134716

# %%
loss = hist.history['loss']
val_loss = hist.history['val_loss']
epochs = range(len(loss))
plt.figure()
plt.plot(epochs, loss, 'bo', label = 'Training loss')
plt.plot(epochs, val_loss, 'b', label = 'Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()
