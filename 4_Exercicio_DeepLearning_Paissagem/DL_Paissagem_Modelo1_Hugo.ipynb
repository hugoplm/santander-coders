# %% [markdown]
# <a href="https://colab.research.google.com/github/hugoplm/santander-coders/blob/master/4_Exercicio_DeepLearning_Paissagem/DL_Paissagem_Modelo1_Hugo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Baixando os Dados

# %%
# !pip install -Uqqq gdown

# %%
# !gdown 1ORgjWsWnGHdmi7wOZZV64GbQNE4SXkh7
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ORgjWsWnGHdmi7wOZZV64GbQNE4SXkh7
# To: /content/seg_train.zip
# 100% 215M/215M [00:01<00:00, 113MB/s]

# %%
import shutil

# %%
shutil.unpack_archive('seg_train.zip', 'data')

# %% [markdown]
# # Carregando os Dados

# %%
import glob
import cv2
import numpy as np
import matplotlib.pyplot as plt
from random import randint
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split

# %%
path = "/content/data/seg_train/**/*.jpg"

# %%
X = []
y = []

for files in glob.glob(path, recursive=True):
  image = cv2.imread(files)
  image = cv2.resize(image, (125,125))
  X.append(image)
  y.append(files.split('/')[-2])

# %%
X = np.array(X)
y = np.array(y)
print(X.shape)
print(y.shape)
# Out:
# (14034, 125, 125, 3)
# (14034,)

# %%
f, ax = plt.subplots(5,5)
f.subplots_adjust(0,0,3,3)
for i in range(0,5,1):
  for j in range(0,5,1):
    rnd_number = randint(0,len(X))
    ax[i,j].imshow(X[rnd_number])
    ax[i,j].set_title(y[rnd_number])
    ax[i,j].axis('off')

# %% [markdown]
# # Pré-processamento dos Dados

# %%
X_train, X_val, y_train, y_val = train_test_split(
     X, y, stratify=y, test_size=0.33, random_state=42)

# %%
hot = OneHotEncoder()
y_train = hot.fit_transform(y_train.reshape(-1,1)).toarray()
y_val = hot.transform(y_val.reshape(-1,1)).toarray()

# %%
X_train = X_train / 255
X_val = X_val / 255

# %% [markdown]
# Distribuição das Classes

# %%
import seaborn as sns
sns.countplot(y);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# #Modelo Deep Learning

# %% [markdown]
# ## Carregando as Bibliotecas

# %%
from tensorflow.python.keras.layers import Input, Dense, Activation, Dropout, Flatten
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.callbacks import EarlyStopping

from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Modelo 1
#
# Modelo para baseline

# %% [markdown]
# ### Definição da Arquitetura

# %%
rede = Sequential()

rede.add(Flatten())
rede.add(Dense(25,  input_dim = X_train.shape[1]*X_train.shape[2]*X_train.shape[3]))
rede.add(Activation('relu'))
rede.add(Dense(25))
rede.add(Activation('relu'))
rede.add(Dense(6))
rede.add(Activation('softmax'))

# %%
es = EarlyStopping(monitor = 'val_loss', 
                   min_delta = 0.001, 
                   patience = 10, 
                   verbose = 1, 
                   mode = 'auto')

# %%
rede.compile(loss = 'categorical_crossentropy', 
              optimizer = 'Adam', 
              metrics=['accuracy'])

# %% [markdown]
# ### Treinamento do Modelo

# %%
hist = rede.fit(X_train, 
                y_train, 
                epochs = 25,
                batch_size=32,
                verbose = 1,
                validation_data = (X_val, y_val),
                callbacks = [es])
# Out:
# Epoch 1/25
# 294/294 [==============================] - 8s 24ms/step - loss: 1.9193 - accuracy: 0.3496 - val_loss: 1.5450 - val_accuracy: 0.3869
# Epoch 2/25
# 294/294 [==============================] - 6s 20ms/step - loss: 1.4664 - accuracy: 0.4009 - val_loss: 1.3949 - val_accuracy: 0.4357
# Epoch 3/25
# 294/294 [==============================] - 6s 20ms/step - loss: 1.3933 - accuracy: 0.4374 - val_loss: 1.3700 - val_accuracy: 0.4514
# Epoch 4/25
# 294/294 [==============================] - 6s 20ms/step - loss: 1.4127 - accuracy: 0.4301 - val_loss: 1.3785 - val_accuracy: 0.4618
# Epoch 5/25
# 294/294 [==============================] - 6s 20ms/step - loss: 1.3563 - accuracy: 0.4615 - val_loss: 1.4279 - val_accuracy: 0.4152
# Epoch 6/25
# 294/294 [==============================] - 6s 20ms/step - loss: 1.3718 - accuracy: 0.4553 - val_loss: 1.3793 - val_accuracy: 0.4465
# Epoch 7/25
# 294/294 [==============================] - 6s 20ms/step - loss: 1.3317 - accuracy: 0.4750 - val_loss: 1.3466 - val_accuracy: 0.4482
# Epoch 8/25
# 294/294 [==============================] - 6s 20ms/step - loss: 1.3153 - accuracy: 0.4825 - val_loss: 1.3071 - val_accuracy: 0.4711
# Epoch 9/25
# 294/294 [==============================] - 6s 19ms/step - loss: 1.3029 - accuracy: 0.4863 - val_loss: 1.3947 - val_accuracy: 0.4624
# Epoch 10/25
# 294/294 [==============================] - 6s 20ms/step - loss: 1.2918 - accuracy: 0.4920 - val_loss: 1.3646 - val_accuracy: 0.4624
# Epoch 11/25
# 294/294 [==============================] - 8s 26ms/step - loss: 1.2945 - accuracy: 0.4953 - val_loss: 1.2993 - val_accuracy: 0.4961
# Epoch 12/25
# 294/294 [==============================] - 6s 22ms/step - loss: 1.2746 - accuracy: 0.5017 - val_loss: 1.3479 - val_accuracy: 0.4691
# Epoch 13/25
# 294/294 [==============================] - 6s 20ms/step - loss: 1.2582 - accuracy: 0.5127 - val_loss: 1.4162 - val_accuracy: 0.4760
# Epoch 14/25
# 294/294 [==============================] - 6s 20ms/step - loss: 1.2752 - accuracy: 0.5012 - val_loss: 1.2975 - val_accuracy: 0.4953
# Epoch 15/25
# 294/294 [==============================] - 6s 20ms/step - loss: 1.2414 - accuracy: 0.5098 - val_loss: 1.2782 - val_accuracy: 0.5101
# Epoch 16/25
# 294/294 [==============================] - 6s 20ms/step - loss: 1.2857 - accuracy: 0.4896 - val_loss: 1.3115 - val_accuracy: 0.4940
# Epoch 17/25
# 294/294 [==============================] - 6s 20ms/step - loss: 1.2289 - accuracy: 0.5221 - val_loss: 1.2782 - val_accuracy: 0.5110
# Epoch 18/25
# 294/294 [==============================] - 6s 20ms/step - loss: 1.2438 - accuracy: 0.5133 - val_loss: 1.3328 - val_accuracy: 0.4795
# Epoch 19/25
# 294/294 [==============================] - 6s 20ms/step - loss: 1.2128 - accuracy: 0.5274 - val_loss: 1.3973 - val_accuracy: 0.4411
# Epoch 20/25
# 294/294 [==============================] - 6s 20ms/step - loss: 1.2092 - accuracy: 0.5303 - val_loss: 1.3714 - val_accuracy: 0.4646
# Epoch 21/25
# 294/294 [==============================] - 6s 20ms/step - loss: 1.1925 - accuracy: 0.5358 - val_loss: 1.3655 - val_accuracy: 0.4644
# Epoch 22/25
# 294/294 [==============================] - 6s 20ms/step - loss: 1.1948 - accuracy: 0.5383 - val_loss: 1.4376 - val_accuracy: 0.4447
# Epoch 23/25
# 294/294 [==============================] - 6s 20ms/step - loss: 1.2002 - accuracy: 0.5329 - val_loss: 1.4341 - val_accuracy: 0.4385
# Epoch 24/25
# 294/294 [==============================] - 6s 20ms/step - loss: 1.1976 - accuracy: 0.5350 - val_loss: 1.3268 - val_accuracy: 0.4927
# Epoch 25/25
# 294/294 [==============================] - 6s 20ms/step - loss: 1.1773 - accuracy: 0.5442 - val_loss: 1.3018 - val_accuracy: 0.4942
# Epoch 00025: early stopping

# %% [markdown]
# ### Avaliação do Modelo

# %%
pred = rede.predict(X_val)

accuracy_score(y_val.argmax(1), pred.argmax(1))
# Out:
# 0.49417098445595853

# %%
loss = hist.history['loss']
val_loss = hist.history['val_loss']
epochs = range(len(loss))
plt.figure()
plt.plot(epochs, loss, 'bo', label = 'Training loss')
plt.plot(epochs, val_loss, 'b', label = 'Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()
