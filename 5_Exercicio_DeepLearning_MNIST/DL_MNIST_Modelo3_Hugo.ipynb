# %% [markdown]
# <a href="https://colab.research.google.com/github/hugoplm/santander-coders/blob/master/5_Exercicio_DeepLearning_MNIST/DL_MNIST_Modelo3_Hugo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Carregando os Dados

# %% [markdown]
# Informações do Dataset
#
# This is a dataset of 60,000 28x28 grayscale images of the 10 digits, along with a test set of 10,000 images
#
#
# - Returns
#
# Tuple of NumPy arrays: (x_train, y_train), (x_test, y_test).

# %%
from tensorflow import keras
import cv2
import numpy as np
import matplotlib.pyplot as plt
from random import randint
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split

# %%
(X_train_raw, y_train_raw), (X_test_raw, y_test_raw) = keras.datasets.fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step

# %%
print("X_train: ", X_train_raw.shape)
print("y_train: ", y_train_raw.shape)
print("X_test:  ", X_test_raw.shape)
print("y_test:  ", y_test_raw.shape)
# Out:
# X_train:  (60000, 28, 28)
# y_train:  (60000,)
# X_test:   (10000, 28, 28)
# y_test:   (10000,)

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
f, ax = plt.subplots(5,5)
f.subplots_adjust(0,0,1.5,1.5)
for i in range(0,5,1):
  for j in range(0,5,1):
    rnd_number = randint(0,len(X_train_raw))
    ax[i,j].imshow(X_train_raw[rnd_number], cmap=plt.cm.binary)
    ax[i,j].set_title(class_names[y_train_raw[rnd_number]])
    ax[i,j].axis('off')

# %% [markdown]
# # Pré-processamento dos Dados

# %%
X_train, X_val, y_train, y_val = train_test_split(
     X_train_raw, y_train_raw, stratify=y_train_raw, test_size=0.33, random_state=42)

# %%
hot = OneHotEncoder()
y_train = hot.fit_transform(y_train.reshape(-1,1)).toarray()
y_val = hot.transform(y_val.reshape(-1,1)).toarray()

# %%
X_train = X_train / 255
X_val = X_val / 255

# %%
print(X_train.shape)
print(X_val.shape)
print(y_train.shape)
print(y_val.shape)
# Out:
# (40200, 28, 28)
# (19800, 28, 28)
# (40200, 10)
# (19800, 10)

# %% [markdown]
# Distribuição das Classes

# %%
import seaborn as sns
sns.countplot(y_train_raw);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# #Modelo Deep Learning

# %% [markdown]
# ## Carregando as Bibliotecas

# %%
from tensorflow.python.keras.layers import Input, Dense, Activation, Dropout, Flatten
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.callbacks import EarlyStopping

from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Modelo 3
#
# Maior quantidade de camadas e de neurônios

# %% [markdown]
# ### Definição da Arquitetura

# %%
rede = Sequential()

rede.add(Flatten())
rede.add(Dense(25,  input_dim = X_train.shape[1]*X_train.shape[2]))
rede.add(Activation('relu'))
rede.add(Dense(64))
rede.add(Activation('relu'))
rede.add(Dense(64))
rede.add(Activation('relu'))
rede.add(Dense(128))
rede.add(Activation('relu'))
rede.add(Dense(128))
rede.add(Activation('relu'))
rede.add(Dense(10))
rede.add(Activation('softmax'))

# %%
es = EarlyStopping(monitor = 'val_loss', 
                   min_delta = 0.001, 
                   patience = 10, 
                   verbose = 1, 
                   mode = 'auto')

# %%
rede.compile(loss = 'categorical_crossentropy', 
              optimizer = 'Adam', 
              metrics=['accuracy'])

# %% [markdown]
# ### Treinamento do Modelo

# %%
hist = rede.fit(X_train, 
                y_train, 
                epochs = 50,
                batch_size=50,
                verbose = 1,
                validation_data = (X_val, y_val),
                callbacks = [es])
# Out:
# Epoch 1/50
# 804/804 [==============================] - 6s 3ms/step - loss: 0.6251 - accuracy: 0.7689 - val_loss: 0.4323 - val_accuracy: 0.8457
# Epoch 2/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4322 - accuracy: 0.8406 - val_loss: 0.4081 - val_accuracy: 0.8477
# Epoch 3/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.3957 - accuracy: 0.8519 - val_loss: 0.4031 - val_accuracy: 0.8508
# Epoch 4/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.3687 - accuracy: 0.8629 - val_loss: 0.3649 - val_accuracy: 0.8679
# Epoch 5/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.3574 - accuracy: 0.8672 - val_loss: 0.3402 - val_accuracy: 0.8765
# Epoch 6/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.3390 - accuracy: 0.8737 - val_loss: 0.3469 - val_accuracy: 0.8752
# Epoch 7/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.3289 - accuracy: 0.8759 - val_loss: 0.3510 - val_accuracy: 0.8744
# Epoch 8/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.3200 - accuracy: 0.8805 - val_loss: 0.3817 - val_accuracy: 0.8656
# Epoch 9/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.3081 - accuracy: 0.8850 - val_loss: 0.3610 - val_accuracy: 0.8752
# Epoch 10/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.3020 - accuracy: 0.8868 - val_loss: 0.3433 - val_accuracy: 0.8752
# Epoch 11/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.2964 - accuracy: 0.8893 - val_loss: 0.3763 - val_accuracy: 0.8682
# Epoch 12/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.2900 - accuracy: 0.8902 - val_loss: 0.3558 - val_accuracy: 0.8749
# Epoch 13/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.2837 - accuracy: 0.8944 - val_loss: 0.3361 - val_accuracy: 0.8848
# Epoch 14/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.2796 - accuracy: 0.8947 - val_loss: 0.3514 - val_accuracy: 0.8742
# Epoch 15/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.2747 - accuracy: 0.8962 - val_loss: 0.3279 - val_accuracy: 0.8863
# Epoch 16/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.2664 - accuracy: 0.8989 - val_loss: 0.3309 - val_accuracy: 0.8848
# Epoch 17/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.2603 - accuracy: 0.9009 - val_loss: 0.3382 - val_accuracy: 0.8854
# Epoch 18/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.2560 - accuracy: 0.9028 - val_loss: 0.3410 - val_accuracy: 0.8833
# Epoch 19/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.2532 - accuracy: 0.9052 - val_loss: 0.3527 - val_accuracy: 0.8791
# Epoch 20/50
# 804/804 [==============================] - 4s 5ms/step - loss: 0.2470 - accuracy: 0.9066 - val_loss: 0.3561 - val_accuracy: 0.8808
# Epoch 21/50
# 804/804 [==============================] - 3s 4ms/step - loss: 0.2450 - accuracy: 0.9070 - val_loss: 0.3436 - val_accuracy: 0.8830
# Epoch 22/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.2426 - accuracy: 0.9064 - val_loss: 0.3571 - val_accuracy: 0.8864
# Epoch 23/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.2348 - accuracy: 0.9084 - val_loss: 0.3557 - val_accuracy: 0.8823
# Epoch 24/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.2319 - accuracy: 0.9094 - val_loss: 0.3563 - val_accuracy: 0.8835
# Epoch 25/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.2277 - accuracy: 0.9115 - val_loss: 0.3766 - val_accuracy: 0.8783
# Epoch 00025: early stopping

# %% [markdown]
# ### Avaliação do Modelo

# %%
pred = rede.predict(X_val)

accuracy_score(y_val.argmax(1), pred.argmax(1))
# Out:
# 0.8783333333333333

# %%
loss = hist.history['loss']
val_loss = hist.history['val_loss']
epochs = range(len(loss))
plt.figure()
plt.plot(epochs, loss, 'bo', label = 'Training loss')
plt.plot(epochs, val_loss, 'b', label = 'Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %% [markdown]
# # Avaliação do Modelo com os Dados de Teste

# %%
f, ax = plt.subplots(5,5)
f.subplots_adjust(0,0,1.5,1.5)
for i in range(0,5,1):
  for j in range(0,5,1):
    rnd_number = randint(0,len(X_test_raw))
    ax[i,j].imshow(X_test_raw[rnd_number], cmap=plt.cm.binary)
    ax[i,j].set_title(class_names[y_test_raw[rnd_number]])
    ax[i,j].axis('off')

# %% [markdown]
# Pré-processamento dos Dados de Teste

# %%
X_test = X_test_raw / 255
y_test = hot.transform(y_test_raw.reshape(-1,1)).toarray()

# %% [markdown]
# Avaliação do Modelo

# %%
pred = rede.predict(X_test)

accuracy_score(y_test.argmax(1), pred.argmax(1))
# Out:
# 0.8697
