# %% [markdown]
# <a href="https://colab.research.google.com/github/hugoplm/santander-coders/blob/master/5_Exercicio_DeepLearning_MNIST/DL_MNIST_Modelo1_Hugo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Carregando os Dados

# %% [markdown]
# Informações do Dataset
#
# This is a dataset of 60,000 28x28 grayscale images of the 10 digits, along with a test set of 10,000 images
#
#
# - Returns
#
# Tuple of NumPy arrays: (x_train, y_train), (x_test, y_test).

# %%
from tensorflow import keras
import cv2
import numpy as np
import matplotlib.pyplot as plt
from random import randint
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split

# %%
(X_train_raw, y_train_raw), (X_test_raw, y_test_raw) = keras.datasets.fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step

# %%
print("X_train: ", X_train_raw.shape)
print("y_train: ", y_train_raw.shape)
print("X_test:  ", X_test_raw.shape)
print("y_test:  ", y_test_raw.shape)
# Out:
# X_train:  (60000, 28, 28)
# y_train:  (60000,)
# X_test:   (10000, 28, 28)
# y_test:   (10000,)

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
f, ax = plt.subplots(5,5)
f.subplots_adjust(0,0,1.5,1.5)
for i in range(0,5,1):
  for j in range(0,5,1):
    rnd_number = randint(0,len(X_train_raw))
    ax[i,j].imshow(X_train_raw[rnd_number], cmap=plt.cm.binary)
    ax[i,j].set_title(class_names[y_train_raw[rnd_number]])
    ax[i,j].axis('off')

# %% [markdown]
# # Pré-processamento dos Dados

# %%
X_train, X_val, y_train, y_val = train_test_split(
     X_train_raw, y_train_raw, stratify=y_train_raw, test_size=0.33, random_state=42)

# %%
hot = OneHotEncoder()
y_train = hot.fit_transform(y_train.reshape(-1,1)).toarray()
y_val = hot.transform(y_val.reshape(-1,1)).toarray()

# %%
X_train = X_train / 255
X_val = X_val / 255

# %%
print(X_train.shape)
print(X_val.shape)
print(y_train.shape)
print(y_val.shape)
# Out:
# (40200, 28, 28)
# (19800, 28, 28)
# (40200, 10)
# (19800, 10)

# %% [markdown]
# Distribuição das Classes

# %%
import seaborn as sns
sns.countplot(y_train_raw);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# #Modelo Deep Learning

# %% [markdown]
# ## Carregando as Bibliotecas

# %%
from tensorflow.python.keras.layers import Input, Dense, Activation, Dropout, Flatten
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.callbacks import EarlyStopping

from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Modelo 1
#
# Modelo para baseline

# %% [markdown]
# ### Definição da Arquitetura

# %%
rede = Sequential()

rede.add(Flatten())
rede.add(Dense(25,  input_dim = X_train.shape[1]*X_train.shape[2]))
rede.add(Activation('relu'))
rede.add(Dense(25))
rede.add(Activation('relu'))
rede.add(Dense(10))
rede.add(Activation('softmax'))

# %%
es = EarlyStopping(monitor = 'val_loss', 
                   min_delta = 0.001, 
                   patience = 10, 
                   verbose = 1, 
                   mode = 'auto')

# %%
rede.compile(loss = 'categorical_crossentropy', 
              optimizer = 'Adam', 
              metrics=['accuracy'])

# %% [markdown]
# ### Treinamento do Modelo

# %%
hist = rede.fit(X_train, 
                y_train, 
                epochs = 50,
                batch_size=50,
                verbose = 1,
                validation_data = (X_val, y_val),
                callbacks = [es])
# Out:
# Epoch 1/50
# 804/804 [==============================] - 7s 4ms/step - loss: 0.6525 - accuracy: 0.7841 - val_loss: 0.4658 - val_accuracy: 0.8343
# Epoch 2/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4577 - accuracy: 0.8396 - val_loss: 0.4530 - val_accuracy: 0.8392
# Epoch 3/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4229 - accuracy: 0.8508 - val_loss: 0.4202 - val_accuracy: 0.8543
# Epoch 4/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4001 - accuracy: 0.8564 - val_loss: 0.3960 - val_accuracy: 0.8601
# Epoch 5/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.3814 - accuracy: 0.8616 - val_loss: 0.3844 - val_accuracy: 0.8636
# Epoch 6/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.3670 - accuracy: 0.8668 - val_loss: 0.3735 - val_accuracy: 0.8679
# Epoch 7/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.3538 - accuracy: 0.8711 - val_loss: 0.3774 - val_accuracy: 0.8680
# Epoch 8/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.3421 - accuracy: 0.8759 - val_loss: 0.3545 - val_accuracy: 0.8772
# Epoch 9/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.3339 - accuracy: 0.8782 - val_loss: 0.3653 - val_accuracy: 0.8701
# Epoch 10/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.3292 - accuracy: 0.8799 - val_loss: 0.3725 - val_accuracy: 0.8666
# Epoch 11/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.3196 - accuracy: 0.8825 - val_loss: 0.3612 - val_accuracy: 0.8754
# Epoch 12/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.3103 - accuracy: 0.8855 - val_loss: 0.3608 - val_accuracy: 0.8706
# Epoch 13/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.3060 - accuracy: 0.8872 - val_loss: 0.3542 - val_accuracy: 0.8724
# Epoch 14/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.2990 - accuracy: 0.8909 - val_loss: 0.3531 - val_accuracy: 0.8793
# Epoch 15/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.2952 - accuracy: 0.8904 - val_loss: 0.3420 - val_accuracy: 0.8808
# Epoch 16/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.2885 - accuracy: 0.8931 - val_loss: 0.3532 - val_accuracy: 0.8769
# Epoch 17/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.2821 - accuracy: 0.8952 - val_loss: 0.3527 - val_accuracy: 0.8781
# Epoch 18/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.2775 - accuracy: 0.8967 - val_loss: 0.3612 - val_accuracy: 0.8762
# Epoch 19/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.2739 - accuracy: 0.8981 - val_loss: 0.3441 - val_accuracy: 0.8806
# Epoch 20/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.2722 - accuracy: 0.9002 - val_loss: 0.3431 - val_accuracy: 0.8815
# Epoch 21/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.2673 - accuracy: 0.9014 - val_loss: 0.3417 - val_accuracy: 0.8823
# Epoch 22/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.2624 - accuracy: 0.9033 - val_loss: 0.3574 - val_accuracy: 0.8788
# Epoch 23/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.2582 - accuracy: 0.9044 - val_loss: 0.3549 - val_accuracy: 0.8790
# Epoch 24/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.2549 - accuracy: 0.9050 - val_loss: 0.3664 - val_accuracy: 0.8740
# Epoch 25/50
# 804/804 [==============================] - 3s 3ms/step - loss: 0.2535 - accuracy: 0.9057 - val_loss: 0.3466 - val_accuracy: 0.8844
# Epoch 00025: early stopping

# %% [markdown]
# ### Avaliação do Modelo

# %%
pred = rede.predict(X_val)

accuracy_score(y_val.argmax(1), pred.argmax(1))
# Out:
# 0.8844444444444445

# %%
loss = hist.history['loss']
val_loss = hist.history['val_loss']
epochs = range(len(loss))
plt.figure()
plt.plot(epochs, loss, 'bo', label = 'Training loss')
plt.plot(epochs, val_loss, 'b', label = 'Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()
